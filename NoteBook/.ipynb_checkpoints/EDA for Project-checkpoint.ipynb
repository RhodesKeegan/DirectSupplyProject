# %%
from glob import glob

import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

# %%
files = glob('./generic_search_data/*.csv')

file_dict = {}

dfs = []
    
for i in range(len(files)):
    file = open(files[i], 'r', encoding='utf-8')
    lines = file.readlines()[1:]
    file_dict[i] = lines
    dfs.append(pd.read_csv(files[i]))

# %% [markdown]
# Choosing a random example from the data frames and seeing what it contains

# %%
dfs[3].head()
# Out:
#    Unnamed: 0  h3 filter  h2 filter  \
# 0           0        NaN        NaN
# 1           1        NaN        NaN
# 2           2        NaN        NaN
# 3           3        NaN        NaN
# 4           4        NaN        NaN
#
#                                             p filter  div filter  h1 filter  \
# 0  Every PTAC manufacturer recommends a complete ...         NaN        NaN
# 1                                                NaN         NaN        NaN
# 2                                                NaN         NaN        NaN
# 3                                                NaN         NaN        NaN
# 4                                                NaN         NaN        NaN
#
#    span filter  li filter  h3 coil  h2 coil  ... h1 repair  span repair  \
# 0          NaN        NaN      NaN      NaN  ...       NaN          NaN
# 1          NaN        NaN      NaN      NaN  ...       NaN          NaN
# 2          NaN        NaN      NaN      NaN  ...       NaN          NaN
# 3          NaN        NaN      NaN      NaN  ...       NaN          NaN
# 4          NaN        NaN      NaN      NaN  ...       NaN          NaN
#
#    li repair h3 maintenance h2 maintenance  \
# 0        NaN            NaN            NaN
# 1        NaN            NaN            NaN
# 2        NaN            NaN            NaN
# 3        NaN            NaN            NaN
# 4        NaN            NaN            NaN
#
#                                        p maintenance  div maintenance  \
# 0  PTACs are self contained and are installed thr...              NaN
# 1                                   PTAC Maintenance              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   h1 maintenance                       span maintenance  \
# 0            NaN  Ductless Mini-Split Maintenance Guide
# 1            NaN                                    NaN
# 2            NaN                                    NaN
# 3            NaN                                    NaN
# 4            NaN                                    NaN
#
#                           li maintenance
# 0  Ductless Mini-Split Maintenance Guide
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 36 columns]

# %%
removed_entries = []
for entry in file_dict:
    if not file_dict[entry]:
        removed_entries.append(entry)
        
for element in removed_entries:
    file_dict.pop(element)

# %%
# array where each entry is the entire text for each link
raw_text = []

for entry in file_dict:
    string = ' '.join([str(item) for item in file_dict[entry]])
    raw_text.append(string)

# %%
def clean(text):
    text = re.sub(r"[^a-zA-Z]+", ' ', text)
    text = text.lower()
    return text


cleaned_text = list(map(lambda x: clean(x), raw_text))

# %%
print(cleaned_text)
# Out:
# [' if your house does not have enough indoor space for a furnace coil or air handler then a packaged ac that fits outside your house is just right for you bathroom vent fans repair asbestos taping with duct tape this in turn will reduce frequent breakdowns of your ac help you avoid the extra expenditure on repairs and enhance the lifespan of your air conditioner backed by his year remodeling career danny served as the home improvement expert for cbs s the early show and the weather channel for more than a decade his extensive hands on experience and understanding of the industry make him the go to source for all things having to do with the home from advice on simple repairs to complete remodels to helping homeowners prepare their homes for extreme weather and seasons clean and repair decks despite the fact that you need to look into the maintenance of your ac every few months an annual tune up is a must heating cooling maintenance bathroom vent fans repair asbestos taping with duct tape electrical install repair heating cooling maintenance flooring install repair heating cooling maintenance plumbing install repair heating cooling maintenance roof install repair home maintenance wall ceiling repair water heater repair clean and repair decks electrical install repair flooring install repair plumbing install repair roof install repair wall ceiling repair water heater repair home repair home repairs ', ' every ptac manufacturer recommends a complete cleaning at least once per year or more if local conditions warrant in dusty or corrosive environments such as near construction sites or salt water cleaning must be performed more often up to four times a year in addition to cleaning ptac s filters fans fan shrouds drain passages and base pan the all important coils must be thoroughly cleaned ptacs are self contained and are installed through the exterior wall of the building by means of a standard size wall sleeve they have both an evaporator coil and a condensing coil as well as a compressor they re basically a complete climate control system in a box just like any other climate control system to ensure efficiency ptacs require maintenance and cleaning including coil cleaning coilshot condenser cleaner coilshot condenser cleaner every ptac manufacturer recommends a complete cleaning at least once per year or more if local conditions warrant in dusty or corrosive environments such as near construction sites or salt water cleaning must be performed more often up to four times a year in addition to cleaning ptac s filters fans fan shrouds drain passages and base pan the all important coils must be thoroughly cleaned ptacs are self contained and are installed through the exterior wall of the building by means of a standard size wall sleeve they have both an evaporator coil and a condensing coil as well as a compressor they re basically a complete climate control system in a box just like any other climate control system to ensure efficiency ptacs require maintenance and cleaning including coil cleaning ductless mini split maintenance guide ductless mini split maintenance guide coiljet cleaning ptac coiljet coil cleaner coiljet coil cleaner ptac maintenance every ptac manufacturer recommends a complete cleaning at least once per year or more if local conditions warrant in dusty or corrosive environments such as near construction sites or salt water cleaning must be performed more often up to four times a year in addition to cleaning ptac s filters fans fan shrouds drain passages and base pan the all important coils must be thoroughly cleaned coiljet cj e coil cleaner coiljet cj e coil cleaner flowjet coil cleaner system flowjet coil cleaner system speedyfoam coil cleaner speedyfoam coil cleaner dry steam coil surface cleaner dry steam coil surface cleaner contractor coil cleaning guide contractor coil cleaning guide coiljet cj coiljet cj coiljet cj e coiljet cj e coilshot coil cleaning system coilshot coil cleaning system sc vsc dry ste ...

# %% [markdown]
# Making the vectorizer

# %%
vectorizer = CountVectorizer(binary=True)

features = vectorizer.fit_transform(cleaned_text)

# %% [markdown]
# Scaling the data, have to turn off with_mean because we are working with a very sparse matrix

# %%
scaler = StandardScaler(with_mean=False)
scaled_data = scaler.fit_transform(features)

# %%
svd = TruncatedSVD(n_components=5)
decomp = svd.fit_transform(scaled_data)

# %% [markdown]
# Looks like the first and third components yield the highest amount of variance

# %%
plt.scatter([1, 2, 3, 4, 5], svd.explained_variance_ratio_)

# %%
plt.scatter(decomp[:10,0], decomp[:10,1], color='blue', label='First 10 links')
plt.scatter(decomp[10:,0], decomp[10:,1], color='red', label='Remaining links')
plt.legend()
plt.xlabel('comp 1')
plt.ylabel('comp 2');

# %%
temp = decomp[10:,0]
indexes = []
for i in range(len(temp)):
    if temp[i] > 25:
        indexes.append(i)

        
new_decomp_x = np.delete(decomp[10:,0], indexes)
new_decomp_y = np.delete(decomp[10:,1], indexes)

# %%
plt.scatter(decomp[:10,0], decomp[:10,1], color='blue', label='First 10 links')
plt.scatter(new_decomp_x, new_decomp_y, color='red', label='Remaining links')
plt.legend()
plt.xlabel('comp 1')
plt.ylabel('comp 2');
