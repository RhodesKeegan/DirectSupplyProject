# %%
# list of questions
questions = ['What does the mode button do?',
             'Why is the PTAC leaking fluid?',
             'How often should I clean the air filter?',
             'What does PTAC stand for?',
             'Why is the fan not working?',
             'Why is the PTAC so noisy?',
             'Why is there ice forming on my PTAC?',
             'When should should a PTAC be replaced?',
             'Why is the PTAC overheating?',
             'Why is my PTAC not turning on?',
             'Why is the PTAC spitting out water?',
             'Why is the PTAC not cooling the room to the desired temperature?',
             'Why is the PTAC not heating the room to the desired temperature?',
             'How can I make my PTAC more efficient?',
             'How does the cooling work?',
             'What is the maximum temperature that I can set?',
             'How do I change the temperature?',
             'How do I switch between fahrenheit and celsius?',
             'How do I change the fan speed?',
             'What is the LC error code?',
             'What is the FC error code?',
             'What is the AS error code?',
             'What is the ES error code?',
             'What is the CS error code?',
             'What is the OS error code?',
             'What is the HS error code?',
             'What is the LE error code?',
             'What is the LO error code?',
             'What is the FP error code?',
             'What is the HI error code?',
             'What should I do if I get an error code?',
             'How do I remove the front panel?',
             'How do I test the power supply cord?',
             'What should I do if the power supply cord is damaged?',
             'What kind of refrigerant is used?',
             'What is low temperature protection?',
             'What is the recommended gauge for thermostat wire?',
             'How do I clean the air filters?',
             'What should I do if an air filter is torn or damaged?',
             'How often should I clean the vent filter?',
             'Who do I call to request a warranty?',
             'Why does the PTAC vibrate?',
             'How do I turn the PTAC off?',
             'What are the dimensions of the PTAC?',
             'What is the COOL mode?',
             'What is the HEAT mode?',
             'What is the FAN mode?',
             'What does the Constant Fan button do?',
             'How do I fix an AS error code?',
             'How do I fix an E5 error code?',
             'How do I fix a CS error code?',
             'How do I fix an OS error code?',
             'How do I fix a HS error code?',
             'How do I fix an E4 error code?',
             'How do I fix a LE error code?']

# list of corresponding answers
answers = ['This button cycles through the different modes which include COOL, HEAT, and FAN',
           'There is most likely a crack in a pipe or the drain pan. This can be quickly fixed by using water sealant, but the best option is to replace the cracked pipe or pan',
           'The air filter should be cleaned once every two weeks',
           'PTAC stands for Packages Terminal Air Conditioner',
           'The fan motor may be faulty or there could be debris in the way restricting its movement',
           'The fan blades may be loose',
           'Ice can form due to a buildup of dirt and dust within the system',
           'You should change your PTAC unit every 10 years.',
           'This can be caused by not enough refrigerant in the system or a kink in the refrigerant line',
           'Make sure it is properly connected to a reliable power source. If so, use a multi-meter to test to the terminal strip for voltage',
           'The position might need to be adjusted. Make sure the PTAC is level',
           'Check to see that it has refrigerant. If so, the PTAC may need a new thermostat',
           'The PTAC may need a new thermostat',
           'Make sure the unit and air filters are clean',
           'Cooling begins automatically when the room temperature is four degrees below the setpoint',
           'The maximum temperature is eighty four degrees',
           'Press the plus or minus buttons to increase or decrease the temperature',
           'Press and hold both the plus and minus buttons to change between fahrenheit and celsius',
           'Press the button labeled speed to change the speed of the fan',
           'The LC error code indicates that the PTAC control panel is disabled and can only be controlled via the wall thermostat',
           'The FC error code indicates that the PTAC control panel is disabled and can only be controlled via the front desk control',
           'The AS error code indicates there is a room temperature sensor error',
           'The ES error code indicates there is an evaporator temperature sensor error',
           'The CS error code indicates there is a condenser temperature sensor error',
           'The OS error code indicates there is an outside temperature sensor error',
           'The HS error code indicates there is an exhaust temperature sensor error',
           'The LE error code indicates there is a wall thermostat error',
           'The LO error code indicates the room temperature is lower than thirty two degrees',
           'The FP error code indicates the unit is in low temperature protection mode',
           'The HI error code indicates the room temperature is higher than ninety nine degrees',
           'Unplug the unit and plug it back in. If the error persists, look up the error code and how to fix it',
           'Pull out at the bottom to release it from the tabs and then lift up',
           'Plug in the air conditioner, press the TEST button and then press the RESET button. The power supply cord should now be supplying electricity to the unit',
           'The power supply cord must be replaced',
           'The PTAC unit uses R-410A refrigerant',
           'If the unit senses the room temperature to be below thirty two degrees then the fan motor will turn on and warm the room to forty degrees',
           'The recommended wire gauge is 18 to 20 gauge solid thermostat wire',
           'Pull up on the air filter to remove, vacuum off heavy soil, run water through the filter, and dry thoroughly',
           'If the filter is damaged then it should be replaced immediately',
           'You should clean the vent filter twice a year',
           'To request a warranty you can call Directy Supply Equipment and Furnishings at 1-800-634-7328',
           'Make sure the PTAC is secured firmly to the wall',
           'Press the red power button to turn the unit on or off',
           'The dimensions of the PTAC are 42.0x16.0x23.9 inches',
           'This mode cools the room automatically when the room temperature is above the setpoint and stops when the room temperature is 4 degrees below the setpoint',
           'This mode heats the room automatically to the setpoint temperature',
           'This mode uses only the fan without any heating or cooling',
           'While in cooling mode, press this button to turn the constant fan function on or off. This will continuously run the fan',
           'You should check the connection between the temperature sensor and the PCB. If that is fine, then measure the resistance of the sensor',
           'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor',
           'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor',
           'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor',
           'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor',
           'Check the signal wire between the display board and the main board',
           'Check if the wiring between the controller and dip switch board is correct']

# converting the two lists into a dictionary
qa_dict = dict(zip(questions, answers))
print(qa_dict)
# Out:
# {'What does the mode button do': 'This button cycles through the different modes which include COOL, HEAT, and FAN', 'Why is the PTAC leaking fluid': 'There is most likely a crack in a pipe or the drain pan. This can be quickly fixed by using water sealant but the best option is to replace the cracked pipe or pan', 'How often should I clean the air filter': 'The air filter should be cleaned once every two weeks', 'What does PTAC stand for': 'PTAC stands for Packages Terminal Air Conditioner', 'Why is the fan not working': 'The fan motor may be faulty or there could be debris in the way restricting its movement', 'Why is the PTAC so noisy': 'The fan blades may be loose', 'Why is there ice forming on my PTAC': 'Ice can form due to a buildup of dirt and dust within the system', 'When should should a PTAC be replaced': 'You should change your PTAC unit every 10 years.', 'Why is the PTAC overheating': 'This can be caused by not enough refrigerant in the system or a kink in the refrigerant
# ...

# %% [markdown]
# **Questions:**
# 1 - 'What does the mode button do'
# 2 - 'Why is the PTAC leaking fluid'
# 3 - 'How often should I clean the air filter'
# 4 - 'What does PTAC stand for'
# 5 - 'Why is the fan not working'
# 6 - 'Why is the PTAC so noisy'
# 7 - 'Why is there ice forming on my PTAC'
# 8 - 'When should should a PTAC be replaced'
# 9 - 'Why is the PTAC overheating'
# 10 - 'Why is my PTAC not turning on'
# 11 - 'Why is the PTAC spitting out water'
# 12 - 'Why is the PTAC not cooling the room to the desired temperature'
# 13 - 'Why is the PTAC not heating the room to the desired temperature'
# 14 - 'How can I make my PTAC more efficient'
# 15 - 'How does the cooling work'
# 16 - 'What is the maximum temperature that I can set'
# 17 - 'How do I change the temperature'
# 18 - 'How do I switch between fahrenheit and celsius'
# 19 - 'How do I change the fan speed'
# 20 - 'What is the LC error code'
# 21 - 'What is the FC error code'
# 22 - 'What is the AS error code'
# 23 - 'What is the ES error code'
# 24 - 'What is the CS error code'
# 25 - 'What is the OS error code'
# 26 - 'What is the HS error code'
# 27 - 'What is the LE error code'
# 28 - 'What is the LO error code'
# 29 - 'What is the FP error code'
# 30 - 'What is the HI error code'
# 31 - 'What should I do if I get an error code'
# 32 - 'How do I remove the front panel'
# 33 - 'How do I test the power supply cord'
# 34 - 'What should I do if the power supply cord is damaged'
# 35 - 'What kind of refrigerant is used'
# 36 - 'What is low temperature protection'
# 37 - 'What is the recommended gauge for thermostat wire'
# 38 - 'How do I clean the air filters'
# 39 - 'What should I do if an air filter is torn or damaged'
# 40 - 'How often should I clean the vent filter'
# 41 - 'Who do I call to request a warranty'
# 42 - 'Why does the PTAC vibrate'
# 43 - 'How do I turn the PTAC off'
# 44 - 'What are the dimensions of the PTAC'
# 45 - 'What is the COOL mode'
# 46 - 'What is the HEAT mode'
# 47 - 'What is the FAN mode'
# 48 - 'What does the Constant Fan button do'
# 49 - 'How do I fix an AS error code'
# 50 - 'How do I fix an E5 error code'
# 51 - 'How do I fix a CS error code'
# 52 - 'How do I fix an OS error code'
# 53 - 'How do I fix a HS error code'
# 54 - 'How do I fix an E4 error code'
# 55 - 'How do I fix a LE error code'
#
#
# **Answers:**
# 1 - 'This button cycles through the different modes which include COOL, HEAT, and FAN'
# 2 - 'There is most likely a crack in a pipe or the drain pan. This can be quickly fixed by using water sealant but the best option is to replace the cracked pipe or pan'
# 3 - 'The air filter should be cleaned once every two weeks'
# 4 - 'PTAC stands for Packages Terminal Air Conditioner'
# 5 - 'The fan motor may be faulty or there could be debris in the way restricting its movement'
# 6 - 'The fan blades may be loose'
# 7 - 'Ice can form due to a buildup of dirt and dust within the system'
# 8 - 'You should change your PTAC unit every 10 years.'
# 9 - 'This can be caused by not enough refrigerant in the system or a kink in the refrigerant line'
# 10 - 'Make sure it is properly connected to a reliable power source. If so, use a multi-meter to test to the terminal strip for voltage'
# 11 - 'The position might need to be adjusted. Make sure the PTAC is level'
# 12 - 'Check to see that it has refrigerant. If so, the PTAC may need a new thermostat'
# 13 - 'The PTAC may need a new thermostat'
# 14 - 'Make sure the unit and air filters are clean'
# 15 - 'Cooling begins automatically when the room temperature is four degrees below the setpoint'
# 16 - 'The maximum temperature is eighty four degrees'
# 17 - 'Press the plus or minus buttons to increase or decrease the temperature'
# 18 - 'Press and hold both the plus and minus buttons to change between fahrenheit and celsius'
# 19 - 'Press the button labeled speed to change the speed of the fan'
# 20 - 'The LC error code indicates that the PTAC control panel is disabled and can only be controlled via the wall thermostat'
# 21 - 'The FC error code indicates that the PTAC control panel is disabled and can only be controlled via the front desk control'
# 22 - 'The AS error code indicates there is a room temperature sensor error'
# 23 - 'The ES error code indicates there is an evaporator temperature sensor error'
# 24 - 'The CS error code indicates there is a condenser temperature sensor error'
# 25 - 'The OS error code indicates there is an outside temperature sensor error'
# 26 - 'The HS error code indicates there is an exhaust temperature sensor error'
# 27 - 'The LE error code indicates there is a wall thermostat error'
# 28 - 'The LO error code indicates the room temperature is lower than thirty two degrees'
# 29 - 'The FP error code indicates the unit is in low temperature protection mode'
# 30 - 'The HI error code indicates the room temperature is higher than ninety nine degrees'
# 31 - 'Unplug the unit and plug it back in. If the error persists, look up the error code and how to fix it'
# 32 - 'Pull out at the bottom to release it from the tabs and then lift up'
# 33 - 'Plug in the air conditioner, press the TEST button and then press the RESET button. The power supply cord should now be supplying electricity to the unit'
# 34 - 'The power supply cord must be replaced'
# 35 - 'The PTAC unit uses R-410A refrigerant'
# 36 - 'If the unit senses the room temperature to be below thirty two degrees then the fan motor will turn on and warm the room to forty degrees'
# 37 - 'The recommended wire gauge is 18 to 20 gauge solid thermostat wire'
# 38 - 'Pull up on the air filter to remove, vacuum off heavy soil, run water through the filter, and dry thoroughly'
# 39 - 'If the filter is damaged then it should be replaced immediately'
# 40 - 'You should clean the vent filter twice a year'
# 41 - 'To request a warranty you can call Directy Supply Equipment and Furnishings at 1-800-634-7328'
# 42 - 'Make sure the PTAC is secured firmly to the wall'
# 43 - 'Press the red power button to turn the unit on or off'
# 44 - 'The dimensions of the PTAC are 42.0x16.0x23.9 inches'
# 45 - 'This mode cools the room automatically when the room temperature is above the setpoint and stops when the room temperature is 4 degrees below the setpoint'
# 46 - 'This mode heats the room automatically to the setpoint temperature'
# 47 - 'This mode uses only the fan without any heating or cooling'
# 48 - 'While in cooling mode, press this button to turn the constant fan function on or off. This will continuously run the fan'
# 49 - 'You should check the connection between the temperature sensor and the PCB. If that is fine, thenmeasure the resistance of the sensor'
# 50 - 'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor'
# 51 - 'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor'
# 52 - 'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor'
# 53 - 'You should check the connection between the temperature sensor and the PCB  If that is fine, then measure the resistance of the sensor'
# 54 - 'Check the signal wire between the display board and the main board'
# 55 - 'Check if the wiring between the controller and dip switch board is correct'
